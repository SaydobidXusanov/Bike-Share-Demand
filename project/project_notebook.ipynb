# %% [markdown]
# # Predict Bike Sharing Demand with AutoGluon Template

# %% [markdown]
# ## Project: Predict Bike Sharing Demand with AutoGluon
# This notebook is a template with each step that you need to complete for the project.
#
# Please fill in your code where there are explicit `?` markers in the notebook. You are welcome to add more cells and code as you see fit.
#
# Once you have completed all the code implementations, please export your notebook as a HTML file so the reviews can view your code. Make sure you have all outputs correctly outputted.
#
# `File-> Export Notebook As... -> Export Notebook as HTML`
#
# There is a writeup to complete as well after all code implememtation is done. Please answer all questions and attach the necessary tables and charts. You can complete the writeup in either markdown or PDF.
#
# Completing the code template and writeup template will cover all of the rubric points for this project.
#
# The rubric contains "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. The stand out suggestions are optional. If you decide to pursue the "stand out suggestions", you can include the code in this notebook and also discuss the results in the writeup file.

# %% [markdown]
# ## Step 1: Create an account with Kaggle

# %% [markdown]
# ### Create Kaggle Account and download API key
# Below is example of steps to get the API username and key. Each student will have their own username and key.

# %% [markdown]
# 1. Open account settings.
# ![kaggle1.png](attachment:kaggle1.png)
# ![kaggle2.png](attachment:kaggle2.png)
# 2. Scroll down to API and click Create New API Token.
# ![kaggle3.png](attachment:kaggle3.png)
# ![kaggle4.png](attachment:kaggle4.png)
# 3. Open up `kaggle.json` and use the username and key.
# ![kaggle5.png](attachment:kaggle5.png)

# %% [markdown]
# ## Step 2: Download the Kaggle dataset using the kaggle python library

# %% [markdown]
# ### Open up Sagemaker Studio and use starter template

# %% [markdown]
# 1. Notebook should be using a `ml.t3.medium` instance (2 vCPU + 4 GiB)
# 2. Notebook should be using kernal: `Python 3 (MXNet 1.8 Python 3.7 CPU Optimized)`

# %% [markdown]
# ### Install packages

# %%
# !pip install -U pip
# !pip install -U setuptools wheel
# !pip install -U "mxnet<2.0.0" bokeh==2.0.1
# !pip install autogluon --no-cache-dir
# Without --no-cache-dir, smaller aws instances may have trouble installing
# Out:
# Requirement already satisfied: pip in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (23.1.2)
# Collecting pip
#   Using cached pip-24.0-py3-none-any.whl (2.1 MB)
# ERROR: To modify pip, please run the following command:
# C:\Users\hp\AppData\Local\Programs\Python\Python310\python.exe -m pip install -U pip
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: C:\Users\hp\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip
# Requirement already satisfied: setuptools in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (60.2.0)
# Collecting setuptools
#   Using cached setuptools-69.5.1-py3-none-any.whl (894 kB)
# Requirement already satisfied: wheel in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (0.43.0)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 60.2.0
#     Uninstalling setuptools-60.2.0:
#       Successfully uninstalled setuptools-60.2.0
# Successfully installed setuptools-69.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openxlab 0.0.38 requires setuptools~=60.2.0, but you have setuptools 69.5.1 which is incompatible.
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: C:\Users\hp\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip
# Collecting mxnet<2.0.0
#   Using cached mxnet-1.7.0.post2-py2.py3-none-win_amd64.whl (33.1 MB)
# Collecting bokeh==2.0.1
#   Using cached bokeh-2.0.1-py3-none-any.whl
# Requirement already satisfied: PyYAML>=3.10 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from bokeh==2.0.1) (6.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from bokeh==2.0.1) (2.8.2)
# Requirement already satisfied: Jinja2>=2.7 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from bokeh==2.0.1) (3.1.2)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from bokeh==2.0.1) (1.25.0)
# Requirement already satisfied: pillow>=4.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from bokeh==2.0.1) (10.3.0)
# Requirement already satisfied: packaging>=16.8 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from bokeh==2.0.1) (23.1)
# Requirement already satisfied: tornado>=5 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from bokeh==2.0.1) (6.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from bokeh==2.0.1) (4.9.0)
# Collecting numpy>=1.11.3 (from bokeh==2.0.1)
#   Using cached numpy-1.16.6.zip (5.1 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting requests<2.19.0,>=2.18.4 (from mxnet<2.0.0)
#   Using cached requests-2.18.4-py2.py3-none-any.whl (88 kB)
# Collecting graphviz<0.9.0,>=0.8.1 (from mxnet<2.0.0)
#   Using cached graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=2.7->bokeh==2.0.1) (2.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.1->bokeh==2.0.1) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet<2.0.0) (2023.5.7)
# Collecting chardet<3.1.0,>=3.0.2 (from requests<2.19.0,>=2.18.4->mxnet<2.0.0)
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting idna<2.7,>=2.5 (from requests<2.19.0,>=2.18.4->mxnet<2.0.0)
#   Using cached idna-2.6-py2.py3-none-any.whl (56 kB)
# Collecting urllib3<1.23,>=1.21.1 (from requests<2.19.0,>=2.18.4->mxnet<2.0.0)
#   Using cached urllib3-1.22-py2.py3-none-any.whl (132 kB)
# Building wheels for collected packages: numpy
#   Building wheel for numpy (setup.py): started
#   Building wheel for numpy (setup.py): finished with status 'error'
#   Running setup.py clean for numpy
# Failed to build numpy
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [264 lines of output]
#   Running from numpy source directory.
#   C:\Users\hp\AppData\Local\Temp\pip-install-9wd7v9hl\numpy_4a9f4380f73e4fb78fdb4afc3da1ea05\numpy\distutils\misc_util.py:476: SyntaxWarning: "is" with a literal. Did you mean "=="?
#     return is_string(s) and ('*' in s or '?' is s)
#   blas_opt_info:
#   blas_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#     NOT AVAILABLE
#
#   blis_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blis not found in ['C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#     NOT AVAILABLE
#
#   openblas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#   get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#   customize GnuFCompiler
#   Could not locate executable g77
#   Could not locate executable f77
#   customize IntelVisualFCompiler
#   Could not locate executable ifort
#   Could not locate executable ifl
#   customize AbsoftFCompiler
#   Could not locate executable f90
#   customize CompaqVisualFCompiler
#   Could not locate executable DF
#   customize IntelItaniumVisualFCompiler
#   Could not locate executable efl
#   customize Gnu95FCompiler
#   Could not locate executable gfortran
#   Could not locate executable f95
#   customize G95FCompiler
#   Could not locate executable g95
#   customize IntelEM64VisualFCompiler
#   customize IntelEM64TFCompiler
#   Could not locate executable efort
#   Could not locate executable efc
#   customize PGroupFlangCompiler
#   Could not locate executable flang
#   don't know how to compile Fortran code on platform 'nt'
#     NOT AVAILABLE
#
#   atlas_3_10_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas not found in ['C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#     NOT AVAILABLE
#
#   atlas_3_10_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas not found in ['C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#     NOT AVAILABLE
#
#   atlas_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#     NOT AVAILABLE
#
#   atlas_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in ['C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#     NOT AVAILABLE
#
#   accelerate_info:
#     NOT AVAILABLE
#
#   C:\Users\hp\AppData\Local\Temp\pip-install-9wd7v9hl\numpy_4a9f4380f73e4fb78fdb4afc3da1ea05\numpy\distutils\system_info.py:639: UserWarning:
#       Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [atlas]) or by setting
#       the ATLAS environment variable.
#     self.calc_info()
#   blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blas not found in ['C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#     NOT AVAILABLE
#
#   C:\Users\hp\AppData\Local\Temp\pip-install-9wd7v9hl\numpy_4a9f4380f73e4fb78fdb4afc3da1ea05\numpy\distutils\system_info.py:639: UserWarning:
#       Blas (http://www.netlib.org/blas/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [blas]) or by setting
#       the BLAS environment variable.
#     self.calc_info()
#   blas_src_info:
#     NOT AVAILABLE
#
#   C:\Users\hp\AppData\Local\Temp\pip-install-9wd7v9hl\numpy_4a9f4380f73e4fb78fdb4afc3da1ea05\numpy\distutils\system_info.py:639: UserWarning:
#       Blas (http://www.netlib.org/blas/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [blas_src]) or by setting
#       the BLAS_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   'svnversion' is not recognized as an internal or external command,
#   operable program or batch file.
#   non-existing path in 'numpy\\distutils': 'site.cfg'
#   lapack_opt_info:
#   lapack_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#     NOT AVAILABLE
#
#   openblas_lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#     NOT AVAILABLE
#
#   openblas_clapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas,lapack not found in ['C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#     NOT AVAILABLE
#
#   atlas_3_10_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\hp\AppData\Local\Programs\Python\Python310\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\hp\AppData\Local\Programs\Python\Python310\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\hp\AppData\Local\Programs\Python\Python310\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\hp\AppData\Local\Programs\Python\Python310\libs
#   <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#     NOT AVAILABLE
#
#   atlas_3_10_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\hp\AppData\Local\Programs\Python\Python310\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\hp\AppData\Local\Programs\Python\Python310\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\hp\AppData\Local\Programs\Python\Python310\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\hp\AppData\Local\Programs\Python\Python310\libs
#   <class 'numpy.distutils.system_info.atlas_3_10_info'>
#     NOT AVAILABLE
#
#   atlas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\hp\AppData\Local\Programs\Python\Python310\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\hp\AppData\Local\Programs\Python\Python310\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\hp\AppData\Local\Programs\Python\Python310\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\hp\AppData\Local\Programs\Python\Python310\libs
#   <class 'numpy.distutils.system_info.atlas_threads_info'>
#     NOT AVAILABLE
#
#   atlas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\hp\AppData\Local\Programs\Python\Python310\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\hp\AppData\Local\Programs\Python\Python310\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\hp\AppData\Local\Programs\Python\Python310\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\hp\AppData\Local\Programs\Python\Python310\libs
#   <class 'numpy.distutils.system_info.atlas_info'>
#     NOT AVAILABLE
#
#   lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack not found in ['C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#     NOT AVAILABLE
#
#   C:\Users\hp\AppData\Local\Temp\pip-install-9wd7v9hl\numpy_4a9f4380f73e4fb78fdb4afc3da1ea05\numpy\distutils\system_info.py:639: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [lapack]) or by setting
#       the LAPACK environment variable.
#     self.calc_info()
#   lapack_src_info:
#     NOT AVAILABLE
#
#   C:\Users\hp\AppData\Local\Temp\pip-install-9wd7v9hl\numpy_4a9f4380f73e4fb78fdb4afc3da1ea05\numpy\distutils\system_info.py:639: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#       the LAPACK_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   C:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\_distutils\dist.py:266: UserWarning: Unknown distribution option: 'define_macros'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building py_modules sources
#   creating build
#   creating build\src.win-amd64-3.1
#   creating build\src.win-amd64-3.1\numpy
#   creating build\src.win-amd64-3.1\numpy\distutils
#   building library "npymath" sources
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for numpy
#   error: subprocess-exited-with-error
#
#   python setup.py clean did not run successfully.
#   exit code: 1
#
#   [10 lines of output]
#   Running from numpy source directory.
#
#   `setup.py clean` is not supported, use one of the following instead:
#
#     - `git clean -xdf` (cleans all files)
#     - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                         files that aren't checked into the git repo)
#
#   Add `--force` to your command to use it anyway if you must (unsupported).
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed cleaning build dir for numpy
# ERROR: Could not build wheels for numpy, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: C:\Users\hp\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip
# Requirement already satisfied: autogluon in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (1.1.0)
# Requirement already satisfied: autogluon.core[all]==1.1.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon) (1.1.0)
# Requirement already satisfied: autogluon.features==1.1.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon) (1.1.0)
# Requirement already satisfied: autogluon.tabular[all]==1.1.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon) (1.1.0)
# Requirement already satisfied: autogluon.multimodal==1.1.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon) (1.1.0)
# Requirement already satisfied: autogluon.timeseries[all]==1.1.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon) (1.1.0)
# Requirement already satisfied: numpy<1.29,>=1.21 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.core[all]==1.1.0->autogluon) (1.25.0)
# Requirement already satisfied: scipy<1.13,>=1.5.4 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.core[all]==1.1.0->autogluon) (1.11.4)
# Requirement already satisfied: scikit-learn<1.4.1,>=1.3.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.core[all]==1.1.0->autogluon) (1.3.2)
# Requirement already satisfied: networkx<4,>=3.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.core[all]==1.1.0->autogluon) (3.3)
# Requirement already satisfied: pandas<2.3.0,>=2.0.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.core[all]==1.1.0->autogluon) (2.0.3)
# Requirement already satisfied: tqdm<5,>=4.38 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.core[all]==1.1.0->autogluon) (4.65.2)
# Requirement already satisfied: requests in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.core[all]==1.1.0->autogluon) (2.28.2)
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.core[all]==1.1.0->autogluon) (3.7.1)
# Requirement already satisfied: boto3<2,>=1.10 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.core[all]==1.1.0->autogluon) (1.24.85)
# Requirement already satisfied: autogluon.common==1.1.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.core[all]==1.1.0->autogluon) (1.1.0)
# Requirement already satisfied: ray[default,tune]<2.11,>=2.10.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.core[all]==1.1.0->autogluon) (2.10.0)
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.core[all]==1.1.0->autogluon) (0.2.7)
# Requirement already satisfied: Pillow<11,>=10.0.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (10.3.0)
# Requirement already satisfied: torch<2.2,>=2.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.1.2)
# Requirement already satisfied: lightning<2.2,>=2.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.1.4)
# Requirement already satisfied: transformers[sentencepiece]<4.39.0,>=4.38.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (4.38.2)
# Requirement already satisfied: accelerate<0.22.0,>=0.21.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.21.0)
# Requirement already satisfied: jsonschema<4.22,>=4.18 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (4.21.1)
# Requirement already satisfied: seqeval<1.3.0,>=1.2.2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.2.2)
# Requirement already satisfied: evaluate<0.5.0,>=0.4.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.4.2)
# Requirement already satisfied: timm<0.10.0,>=0.9.5 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.9.16)
# Requirement already satisfied: torchvision<0.17.0,>=0.16.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.16.2)
# Requirement already satisfied: scikit-image<0.21.0,>=0.19.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.20.0)
# Requirement already satisfied: text-unidecode<1.4,>=1.3 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.3)
# Requirement already satisfied: torchmetrics<1.3.0,>=1.2.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.2.1)
# Requirement already satisfied: nptyping<2.5.0,>=1.4.4 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.4.1)
# Requirement already satisfied: omegaconf<2.3.0,>=2.1.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.2.3)
# Requirement already satisfied: pytorch-metric-learning<2.4,>=1.3.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.3.0)
# Requirement already satisfied: nlpaug<1.2.0,>=1.1.10 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.1.11)
# Requirement already satisfied: nltk<4.0.0,>=3.4.5 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (3.8.1)
# Requirement already satisfied: openmim<0.4.0,>=0.3.7 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.3.9)
# Requirement already satisfied: defusedxml<0.7.2,>=0.7.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.7.1)
# Requirement already satisfied: jinja2<3.2,>=3.0.3 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (3.1.2)
# Requirement already satisfied: tensorboard<3,>=2.9 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (2.16.2)
# Requirement already satisfied: pytesseract<0.3.11,>=0.3.9 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (0.3.10)
# Requirement already satisfied: nvidia-ml-py3==7.352.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (7.352.0)
# Requirement already satisfied: pdf2image<1.19,>=1.17.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.multimodal==1.1.0->autogluon) (1.17.0)
# Requirement already satisfied: xgboost<2.1,>=1.6 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (2.0.3)
# Requirement already satisfied: fastai<2.8,>=2.3.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (2.7.15)
# Requirement already satisfied: lightgbm<4.4,>=3.3 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (4.3.0)
# Requirement already satisfied: catboost<1.3,>=1.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.tabular[all]==1.1.0->autogluon) (1.2.5)
# Requirement already satisfied: joblib<2,>=1.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.timeseries[all]==1.1.0->autogluon) (1.3.2)
# Requirement already satisfied: pytorch-lightning<2.2,>=2.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.timeseries[all]==1.1.0->autogluon) (2.1.4)
# Requirement already satisfied: gluonts<0.14.4,>=0.14.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.timeseries[all]==1.1.0->autogluon) (0.14.3)
# Requirement already satisfied: statsforecast<1.5,>=1.4.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.timeseries[all]==1.1.0->autogluon) (1.4.0)
# Requirement already satisfied: mlforecast<0.10.1,>=0.10.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.timeseries[all]==1.1.0->autogluon) (0.10.0)
# Requirement already satisfied: utilsforecast<0.0.11,>=0.0.10 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.timeseries[all]==1.1.0->autogluon) (0.0.10)
# Requirement already satisfied: orjson~=3.9 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.timeseries[all]==1.1.0->autogluon) (3.10.2)
# Requirement already satisfied: optimum[onnxruntime]<1.19,>=1.17 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.timeseries[all]==1.1.0->autogluon) (1.18.1)
# Requirement already satisfied: psutil<6,>=5.7.3 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.common==1.1.0->autogluon.core[all]==1.1.0->autogluon) (5.9.5)
# Requirement already satisfied: setuptools in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from autogluon.common==1.1.0->autogluon.core[all]==1.1.0->autogluon) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from accelerate<0.22.0,>=0.21.0->autogluon.multimodal==1.1.0->autogluon) (23.1)
# Requirement already satisfied: pyyaml in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from accelerate<0.22.0,>=0.21.0->autogluon.multimodal==1.1.0->autogluon) (6.0)
# Requirement already satisfied: botocore<1.28.0,>=1.27.85 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from boto3<2,>=1.10->autogluon.core[all]==1.1.0->autogluon) (1.27.85)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from boto3<2,>=1.10->autogluon.core[all]==1.1.0->autogluon) (0.10.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from boto3<2,>=1.10->autogluon.core[all]==1.1.0->autogluon) (0.6.0)
# Requirement already satisfied: graphviz in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from catboost<1.3,>=1.1->autogluon.tabular[all]==1.1.0->autogluon) (0.20.3)
# Requirement already satisfied: plotly in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from catboost<1.3,>=1.1->autogluon.tabular[all]==1.1.0->autogluon) (5.15.0)
# Requirement already satisfied: six in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from catboost<1.3,>=1.1->autogluon.tabular[all]==1.1.0->autogluon) (1.16.0)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (2.18.0)
# Requirement already satisfied: dill in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.70.16)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (2024.2.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.21.4)
# Requirement already satisfied: pip in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (23.1.2)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.5.33)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.0.3)
# Requirement already satisfied: spacy<4 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (3.7.4)
# Requirement already satisfied: pydantic<3,>=1.7 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from gluonts<0.14.4,>=0.14.0->autogluon.timeseries[all]==1.1.0->autogluon) (2.7.1)
# Requirement already satisfied: toolz~=0.10 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from gluonts<0.14.4,>=0.14.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.12.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from gluonts<0.14.4,>=0.14.0->autogluon.timeseries[all]==1.1.0->autogluon) (4.9.0)
# Requirement already satisfied: future in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.0->autogluon) (1.0.0)
# Requirement already satisfied: cloudpickle in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.0->autogluon) (3.0.0)
# Requirement already satisfied: py4j in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.0->autogluon) (0.10.9.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from jinja2<3.2,>=3.0.3->autogluon.multimodal==1.1.0->autogluon) (2.1.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.0->autogluon) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.0->autogluon) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.0->autogluon) (0.35.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.0->autogluon) (0.18.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.8.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from lightning<2.2,>=2.1->autogluon.multimodal==1.1.0->autogluon) (0.11.2)
# Requirement already satisfied: numba in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from mlforecast<0.10.1,>=0.10.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.59.1)
# Requirement already satisfied: window-ops in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from mlforecast<0.10.1,>=0.10.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.0.15)
# Requirement already satisfied: gdown>=4.0.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.0->autogluon) (5.1.0)
# Requirement already satisfied: click in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==1.1.0->autogluon) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==1.1.0->autogluon) (2024.4.28)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from omegaconf<2.3.0,>=2.1.1->autogluon.multimodal==1.1.0->autogluon) (4.9.3)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.4.6)
# Requirement already satisfied: model-index in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.1.11)
# Requirement already satisfied: opendatalab in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.0.10)
# Requirement already satisfied: rich in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (13.4.2)
# Requirement already satisfied: tabulate in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.9.0)
# Requirement already satisfied: coloredlogs in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.0->autogluon) (15.0.1)
# Requirement already satisfied: sympy in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.0->autogluon) (1.12)
# Requirement already satisfied: onnx in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.0->autogluon) (1.16.0)
# Requirement already satisfied: onnxruntime>=1.11.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.0->autogluon) (1.17.3)
# Requirement already satisfied: protobuf>=3.20.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.0->autogluon) (4.25.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core[all]==1.1.0->autogluon) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core[all]==1.1.0->autogluon) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core[all]==1.1.0->autogluon) (2023.4)
# Requirement already satisfied: filelock in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (3.13.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (1.0.8)
# Requirement already satisfied: aiosignal in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (1.3.1)
# Requirement already satisfied: frozenlist in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (1.4.1)
# Requirement already satisfied: tensorboardX>=1.9 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (2.6.2.2)
# Requirement already satisfied: pyarrow>=6.0.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (15.0.1)
# Requirement already satisfied: aiohttp>=3.7 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (3.9.3)
# Requirement already satisfied: aiohttp-cors in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (0.7.0)
# Requirement already satisfied: colorful in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (0.3.14)
# Requirement already satisfied: opencensus in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (0.11.4)
# Requirement already satisfied: prometheus-client>=0.7.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (0.17.0)
# Requirement already satisfied: smart-open in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (6.4.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (20.26.1)
# Requirement already satisfied: grpcio>=1.42.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (1.62.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from requests->autogluon.core[all]==1.1.0->autogluon) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from requests->autogluon.core[all]==1.1.0->autogluon) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from requests->autogluon.core[all]==1.1.0->autogluon) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from requests->autogluon.core[all]==1.1.0->autogluon) (2023.5.7)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon) (2.34.1)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon) (2024.4.24)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon) (1.6.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.0->autogluon) (0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn<1.4.1,>=1.3.0->autogluon.core[all]==1.1.0->autogluon) (3.2.0)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from statsforecast<1.5,>=1.4.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.14.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (2.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.0->autogluon) (2.2.2)
# Requirement already satisfied: safetensors in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from timm<0.10.0,>=0.9.5->autogluon.multimodal==1.1.0->autogluon) (0.4.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from transformers[sentencepiece]<4.39.0,>=4.38.0->autogluon.multimodal==1.1.0->autogluon) (0.15.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from transformers[sentencepiece]<4.39.0,>=4.38.0->autogluon.multimodal==1.1.0->autogluon) (0.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->autogluon.core[all]==1.1.0->autogluon) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->autogluon.core[all]==1.1.0->autogluon) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->autogluon.core[all]==1.1.0->autogluon) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->autogluon.core[all]==1.1.0->autogluon) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->autogluon.core[all]==1.1.0->autogluon) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (4.0.3)
# Requirement already satisfied: pyarrow-hotfix in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from datasets>=2.0.0->evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.0->autogluon) (0.6)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.0->autogluon) (4.12.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from numba->mlforecast<0.10.1,>=0.10.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.42.0)
# Requirement already satisfied: flatbuffers in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.11.0->optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.0->autogluon) (24.3.7)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.7->gluonts<0.14.4,>=0.14.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.7->gluonts<0.14.4,>=0.14.0->autogluon.timeseries[all]==1.1.0->autogluon) (2.18.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.9.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (3.4.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from statsmodels>=0.13.2->statsforecast<1.5,>=1.4.0->autogluon.timeseries[all]==1.1.0->autogluon) (0.5.6)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (0.3.8)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (4.2.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from coloredlogs->optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.0->autogluon) (10.0)
# Requirement already satisfied: ordered-set in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from model-index->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (4.1.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (2.19.0)
# Requirement already satisfied: pycryptodome in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (3.20.0)
# Requirement already satisfied: openxlab in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.0.38)
# Requirement already satisfied: pywin32 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (306)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from plotly->catboost<1.3,>=1.1->autogluon.tabular[all]==1.1.0->autogluon) (8.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.15.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from sympy->optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.0->autogluon) (1.3.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (1.63.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (1.23.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (2.29.0)
# Requirement already satisfied: pyreadline3 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from humanfriendly>=9.1->coloredlogs->optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.0->autogluon) (3.4.1)
# Requirement already satisfied: language-data>=1.2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (0.1.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (0.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.0->autogluon) (2.4.1)
# Requirement already satisfied: oss2~=2.17.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.17.0)
# Collecting setuptools (from autogluon.common==1.1.0->autogluon.core[all]==1.1.0->autogluon)
#   Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#                                               0.0/953.1 kB ? eta -:--:--
#      -                                     30.7/953.1 kB 660.6 kB/s eta 0:00:02
#      -                                     30.7/953.1 kB 660.6 kB/s eta 0:00:02
#      --                                    61.4/953.1 kB 409.6 kB/s eta 0:00:03
#      ----                                 112.6/953.1 kB 656.4 kB/s eta 0:00:02
#      ----                                 122.9/953.1 kB 514.3 kB/s eta 0:00:02
#      --------                             225.3/953.1 kB 808.4 kB/s eta 0:00:01
#      --------                             235.5/953.1 kB 846.9 kB/s eta 0:00:01
#      ---------------                        399.4/953.1 kB 1.1 MB/s eta 0:00:01
#      --------------------                   501.8/953.1 kB 1.3 MB/s eta 0:00:01
#      --------------------------             675.8/953.1 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------- 953.1/953.1 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from requests->autogluon.core[all]==1.1.0->autogluon) (1.7.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (4.9)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.0->autogluon) (1.1.0)
# Requirement already satisfied: crcmod>=1.7 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (1.7)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.16.2)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.15.1)
# Requirement already satisfied: cryptography>=2.6.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (42.0.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.0->autogluon) (0.6.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.0->autogluon) (2.21)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 69.5.1
#     Uninstalling setuptools-69.5.1:
#       Successfully uninstalled setuptools-69.5.1
# Successfully installed setuptools-60.2.0
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: C:\Users\hp\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Setup Kaggle API Key

# %%
# create the .kaggle directory and an empty kaggle.json file
# !mkdir -p /root/.kaggle
# !touch /root/.kaggle/kaggle.json
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# The syntax of the command is incorrect.
# 'touch' is not recognized as an internal or external command,
# operable program or batch file.
# 'chmod' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Fill in your user name and key from creating the kaggle account and API token file
import json
kaggle_username = "username"
kaggle_key = "key"

# Save API token the kaggle.json file
with open("../kaggle.json", "w") as f:
    f.write(json.dumps({"username": kaggle_username, "key": kaggle_key}))

# %% [markdown]
# ### Download and explore dataset

# %% [markdown]
# ### Go to the bike sharing demand competition and agree to the terms
# ![kaggle6.png](attachment:kaggle6.png)

# %%
# Download the dataset, it will be in a .zip file so you'll need to unzip it as well.
# !kaggle competitions download -c bike-sharing-demand
# If you already downloaded it you can use the -o command to overwrite the file
# !unzip -o bike-sharing-demand.zip
# Out:
# 'kaggle' is not recognized as an internal or external command,
# operable program or batch file.
# Archive:  bike-sharing-demand.zip
#   inflating: sampleSubmission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
import pandas as pd
from autogluon.tabular import TabularPredictor

# %%
import matplotlib.pyplot as plt

# %%
# Create the train dataset in pandas by reading the csv
# Set the parsing of the datetime column so you can use some of the `dt` features in pandas later
train = pd.read_csv("train.csv", parse_dates=["datetime"])
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
# Simple output of the train dataset to view some of the min/max/varition of the dataset features.
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 1020.7 KB

# %%
train.describe()
# Out:
#                             datetime        season       holiday  \
# count                          10886  10886.000000  10886.000000
# mean   2011-12-27 05:56:22.399411968      2.506614      0.028569
# min              2011-01-01 00:00:00      1.000000      0.000000
# 25%              2011-07-02 07:15:00      2.000000      0.000000
# 50%              2012-01-01 20:30:00      3.000000      0.000000
# 75%              2012-07-01 12:45:00      4.000000      0.000000
# max              2012-12-19 23:00:00      4.000000      1.000000
# std                              NaN      1.116174      0.166599
#
#          workingday       weather         temp         atemp      humidity  \
# count  10886.000000  10886.000000  10886.00000  10886.000000  10886.000000
# mean       0.680875      1.418427     20.23086     23.655084     61.886460
# min        0.000000      1.000000      0.82000      0.760000      0.000000
# 25%        0.000000      1.000000     13.94000     16.665000     47.000000
# 50%        1.000000      1.000000     20.50000     24.240000     62.000000
# 75%        1.000000      2.000000     26.24000     31.060000     77.000000
# max        1.000000      4.000000     41.00000     45.455000    100.000000
# std        0.466159      0.633839      7.79159      8.474601     19.245033
#
#           windspeed        casual    registered         count
# count  10886.000000  10886.000000  10886.000000  10886.000000
# mean      12.799395     36.021955    155.552177    191.574132
# min        0.000000      0.000000      0.000000      1.000000
# 25%        7.001500      4.000000     36.000000     42.000000
# 50%       12.998000     17.000000    118.000000    145.000000
# 75%       16.997900     49.000000    222.000000    284.000000
# max       56.996900    367.000000    886.000000    977.000000
# std        8.164537     49.960477    151.039033    181.144454

# %%
# Create the test pandas dataframe in pandas by reading the csv, remember to parse the datetime!
test = pd.read_csv("test.csv", parse_dates=["datetime"])
test.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
# Same thing as train and test dataset
submission = pd.read_csv("sampleSubmission.csv", parse_dates=["datetime"])
submission.head()
# Out:
#              datetime  count
# 0 2011-01-20 00:00:00      0
# 1 2011-01-20 01:00:00      0
# 2 2011-01-20 02:00:00      0
# 3 2011-01-20 03:00:00      0
# 4 2011-01-20 04:00:00      0

# %% [markdown]
# ## Step 3: Train a model using AutoGluon’s Tabular Prediction

# %% [markdown]
# Requirements:
# * We are prediting `count`, so it is the label we are setting.
# * Ignore `casual` and `registered` columns as they are also not present in the test dataset.
# * Use the `root_mean_squared_error` as the metric to use for evaluation.
# * Set a time limit of 10 minutes (600 seconds).
# * Use the preset `best_quality` to focus on creating the best model.

# %%
predictor = TabularPredictor(label="count").fit(
    train_data=train.drop(labels=["casual", "registered"], axis=1),
    time_limit=600,
    presets="best_quality"
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240502_202103"
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 600 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels\ag-20240502_202103\ds_sub_fit\sub_fit_ho.
# Running the sub-fit in a ray process to avoid memory leakage.
# Spend 186 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 414 seconds.
# Starting full fit now with num_stack_levels 1.
# Beginning AutoGluon training ... Time limit = 414s
# AutoGluon will save models to "AutogluonModels\ag-20240502_202103"
# =================== System Info ===================
# AutoGluon Version:  1.1.0
# Python Version:     3.10.6
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       3.71 GB / 15.72 GB (23.6%)
# Disk Space Avail:   289.51 GB / 375.98 GB (77.0%)
# ===================================================
# Train Data Rows:    10886
# Train Data Columns: 9
# Label Column:       count
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    3798.30 MB
# 	Train Data (Original)  Memory Usage: 0.75 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('datetime', []) : 1 | ['datetime']
# 		('float', [])    : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])      : 5 | ['season', 'holiday', 'workingday', 'weather', 'humidity']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])                  : 3 | ['season', 'weather', 'humidity']
# 		('int', ['bool'])            : 2 | ['holiday', 'workingday']
# 		('int', ['datetime_as_int']) : 5 | ['datetime', 'datetime.year', 'datetime.month', 'datetime.day', 'datetime.dayofweek']
# 	0.1s = Fit runtime
# 	9 features in original data used to generate 13 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.93 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.19s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 275.8s of the 413.78s of remaining time.
# 	-101.5882	 = Validation score   (-root_mean_squared_error)
# 	0.09s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 275.54s of the 413.52s of remaining time.
# 	-84.1464	 = Validation score   (-root_mean_squared_error)
# 	0.12s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 275.23s of the 413.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# 	-131.4609	 = Validation score   (-root_mean_squared_error)
# 	34.14s	 = Training   runtime
# 	12.26s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 229.04s of the 367.03s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.21%)
# 	-131.0542	 = Validation score   (-root_mean_squared_error)
# 	8.55s	 = Training   runtime
# 	1.98s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 214.96s of the 352.94s of remaining time.
# 	-116.5521	 = Validation score   (-root_mean_squared_error)
# 	10.72s	 = Training   runtime
# 	1.05s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 202.25s of the 340.23s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.29%)
# 	-130.467	 = Validation score   (-root_mean_squared_error)
# 	163.68s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 30.87s of the 168.86s of remaining time.
# 	-124.6023	 = Validation score   (-root_mean_squared_error)
# 	5.73s	 = Training   runtime
# 	1.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 22.99s of the 160.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.29%)
# 	-138.2323	 = Validation score   (-root_mean_squared_error)
# 	30.96s	 = Training   runtime
# 	0.84s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 122.6s of remaining time.
# 	Ensemble Weights: {'KNeighborsDist_BAG_L1': 1.0}
# 	-84.1464	 = Validation score   (-root_mean_squared_error)
# 	0.07s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 122.47s of the 122.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.46%)
# 	-60.4519	 = Validation score   (-root_mean_squared_error)
# 	26.62s	 = Training   runtime
# 	6.76s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 86.45s of the 86.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	-54.9978	 = Validation score   (-root_mean_squared_error)
# 	9.04s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 69.67s of the 69.53s of remaining time.
# 	-53.5356	 = Validation score   (-root_mean_squared_error)
# 	55.78s	 = Training   runtime
# 	1.43s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 11.56s of the 11.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# 	-58.6237	 = Validation score   (-root_mean_squared_error)
# 	11.73s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -9.62s of remaining time.
# 	Ensemble Weights: {'RandomForestMSE_BAG_L2': 0.7, 'LightGBM_BAG_L2': 0.25, 'LightGBMXT_BAG_L2': 0.05}
# 	-53.1787	 = Validation score   (-root_mean_squared_error)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 423.73s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240502_202103")

# %% [markdown]
# ### Review AutoGluon's training run with ranking of models that did the best.

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model   score_val              eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L3  -53.178747  root_mean_squared_error      26.398019  345.477811                0.000998           0.041013            3       True         14
# 1   RandomForestMSE_BAG_L2  -53.535642  root_mean_squared_error      18.986094  309.773597                1.431765          55.776312            2       True         12
# 2          LightGBM_BAG_L2  -54.997780  root_mean_squared_error      18.209213  263.035989                0.654884           9.038704            2       True         11
# 3          CatBoost_BAG_L2  -58.623732  root_mean_squared_error      17.610327  265.729158                0.055998          11.731873            2       True         13
# 4        LightGBMXT_BAG_L2  -60.451915  root_mean_squared_error      24.310371  280.621782                6.756042          26.624497            2       True         10
# 5    KNeighborsDist_BAG_L1  -84.146423  root_mean_squared_error       0.083529    0.118999                0.083529           0.118999            1       True          2
# 6      WeightedEnsemble_L2  -84.146423  root_mean_squared_error       0.085507    0.190992                0.001978           0.071993            2       True          9
# 7    KNeighborsUnif_BAG_L1 -101.588176  root_mean_squared_error       0.047997    0.088995                0.047997           0.088995            1       True          1
# 8   RandomForestMSE_BAG_L1 -116.552091  root_mean_squared_error       1.052332   10.721730                1.052332          10.721730            1       True          5
# 9     ExtraTreesMSE_BAG_L1 -124.602302  root_mean_squared_error       1.178890    5.731318                1.178890           5.731318            1       True          7
# 10         CatBoost_BAG_L1 -130.466966  root_mean_squared_error       0.109441  163.680543                0.109441         163.680543            1       True          6
# 11         LightGBM_BAG_L1 -131.054162  root_mean_squared_error       1.983539    8.551771                1.983539           8.551771            1       True          4
# 12       LightGBMXT_BAG_L1 -131.460909  root_mean_squared_error      12.259465   34.140591               12.259465          34.140591            1       True          3
# 13  NeuralNetFastAI_BAG_L1 -138.232340  root_mean_squared_error       0.839136   30.963339                0.839136          30.963339            1       True          8
# Number of models trained: 14
# Types of models trained:
# {'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_CatBoost', 'WeightedEnsembleModel', 'StackerEnsembleModel_RF'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])                : 3 | ['temp', 'atemp', 'windspeed']
# ('int', [])                  : 3 | ['season', 'weather', 'humidity']
# ('int', ['bool'])            : 2 | ['holiday', 'workingday']
# ('int', ['datetime_as_int']) : 5 | ['datetime', 'datetime.year', 'datetime.month', 'datetime.day', 'datetime.dayofweek']
# *** End of fit() summary ***
# C:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': -101.58817625927213,
#   'KNeighborsDist_BAG_L1': -84.14642264302962,
#   'LightGBMXT_BAG_L1': -131.46090891834504,
#   'LightGBM_BAG_L1': -131.054161598899,
#   'RandomForestMSE_BAG_L1': -116.55209143577434,
#   'CatBoost_BAG_L1': -130.46696586241026,
#   'ExtraTreesMSE_BAG_L1': -124.60230209225125,
#   'NeuralNetFastAI_BAG_L1': -138.23234002731658,
#   'WeightedEnsemble_L2': -84.14642264302962,
#   'LightGBMXT_BAG_L2': -60.451915345027416,
#   'LightGBM_BAG_L2': -54.99778036288861,
#   'RandomForestMSE_BAG_L2': -53.53564242863582,
#   'CatBoost_BAG_L2': -58.62373175949499,
#   'WeightedEnsemble_L3': -53.1787465661679},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestMSE_BAG_L1': ['RandomForestMSE_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesMSE_BAG_L1': ['ExtraTreesMSE_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestMSE_BAG_L2': ['RandomForestMSE_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.08899521827697754,
#   'KNeighborsDist_BAG_L1': 0.11899900436401367,
#   'LightGBMXT_BAG_L1': 34.14059090614319,
#   'LightGBM_BAG_L1': 8.551771402359009,
#   'RandomForestMSE_BAG_L1': 10.721729755401611,
#   'CatBoost_BAG_L1': 163.68054294586182,
#   'ExtraTreesMSE_BAG_L1': 5.731317520141602,
#   'NeuralNetFastAI_BAG_L1': 30.963338613510132,
#   'WeightedEnsemble_L2': 0.07199311256408691,
#   'LightGBMXT_BAG_L2': 26.624496936798096,
#   'LightGBM_BAG_L2': 9.038703680038452,
#   'RandomForestMSE_BAG_L2': 55.77631211280823,
#   'CatBoost_BAG_L2': 11.731872797012329,
#   'WeightedEnsemble_L3': 0.04101300239562988},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.04799652099609375,
#   'KNeighborsDist_BAG_L1': 0.08352947235107422,
#   'LightGBMXT_BAG_L1': 12.259465217590332,
#   'LightGBM_BAG_L1': 1.9835388660430908,
#   'RandomForestMSE_BAG_L1': 1.0523321628570557,
#   'CatBoost_BAG_L1': 0.10944056510925293,
#   'ExtraTreesMSE_BAG_L1': 1.1788897514343262,
#   'NeuralNetFastAI_BAG_L1': 0.8391363620758057,
#   'WeightedEnsemble_L2': 0.001977682113647461,
#   'LightGBMXT_BAG_L2': 6.75604248046875,
#   'LightGBM_BAG_L2': 0.6548840999603271,
#   'RandomForestMSE_BAG_L2': 1.4317653179168701,
#   'CatBoost_BAG_L2': 0.05599808692932129,
#   'WeightedEnsemble_L3': 0.000997781753540039},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                      model   score_val              eval_metric  \
#  0      WeightedEnsemble_L3  -53.178747  root_mean_squared_error
#  1   RandomForestMSE_BAG_L2  -53.535642  root_mean_squared_error
#  2          LightGBM_BAG_L2  -54.997780  root_mean_squared_error
#  3          CatBoost_BAG_L2  -58.623732  root_mean_squared_error
#  4        LightGBMXT_BAG_L2  -60.451915  root_mean_squared_error
#  5    KNeighborsDist_BAG_L1  -84.146423  root_mean_squared_error
#  6      WeightedEnsemble_L2  -84.146423  root_mean_squared_error
#  7    KNeighborsUnif_BAG_L1 -101.588176  root_mean_squared_error
#  8   RandomForestMSE_BAG_L1 -116.552091  root_mean_squared_error
#  9     ExtraTreesMSE_BAG_L1 -124.602302  root_mean_squared_error
#  10         CatBoost_BAG_L1 -130.466966  root_mean_squared_error
#  11         LightGBM_BAG_L1 -131.054162  root_mean_squared_error
#  12       LightGBMXT_BAG_L1 -131.460909  root_mean_squared_error
#  13  NeuralNetFastAI_BAG_L1 -138.232340  root_mean_squared_error
#
#      pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  \
#  0       26.398019  345.477811                0.000998           0.041013
#  1       18.986094  309.773597                1.431765          55.776312
#  2       18.209213  263.035989                0.654884           9.038704
#  3       17.610327  265.729158                0.055998          11.731873
#  4       24.310371  280.621782                6.756042          26.624497
#  5        0.083529    0.118999                0.083529           0.118999
#  6        0.085507    0.190992                0.001978           0.071993
#  7        0.047997    0.088995                0.047997           0.088995
#  8        1.052332   10.721730                1.052332          10.721730
#  9        1.178890    5.731318                1.178890           5.731318
#  10       0.109441  163.680543                0.109441         163.680543
#  11       1.983539    8.551771                1.983539           8.551771
#  12      12.259465   34.140591               12.259465          34.140591
#  13       0.839136   30.963339                0.839136          30.963339
#
#      stack_level  can_infer  fit_order
#  0             3       True         14
#  1             2       True         12
#  2             2       True         11
#  3             2       True         13
#  4             2       True         10
#  5             1       True          2
#  6             2       True          9
#  7             1       True          1
#  8             1       True          5
#  9             1       True          7
#  10            1       True          6
#  11            1       True          4
#  12            1       True          3
#  13            1       True          8  }

# %% [markdown]
# ### Create predictions from test dataset

# %%
predictions = predictor.predict(test)
predictions.head()
# Out:
# 0    22.691788
# 1    41.498859
# 2    45.278187
# 3    47.999828
# 4    51.042202
# Name: count, dtype: float32

# %% [markdown]
# #### NOTE: Kaggle will reject the submission if we don't set everything to be > 0.

# %%
# Describe the `predictions` series to see if there are any negative values
predictions.describe()
# Out:
# count    6493.000000
# mean      100.503677
# std        89.605202
# min         3.109341
# 25%        19.391506
# 50%        64.140930
# 75%       166.100357
# max       367.521301
# Name: count, dtype: float64

# %%
# How many negative values do we have?
(predictions < 0).sum()
# Out:
# 0

# %%
# Set them to zero
predictions.loc[predictions < 0] = 0

# %% [markdown]
# ### Set predictions to submission dataframe, save, and submit

# %%
submission["count"] = predictions
submission.to_csv("submission.csv", index=False)

# %%
# !kaggle competitions submit -c bike-sharing-demand -f submission.csv -m "first raw submission"

# %% [markdown]
# #### View submission via the command line or in the web browser under the competition's page - `My Submissions`

# %%
# !kaggle competitions submissions -c bike-sharing-demand | tail -n +1 | head -n 6

# %% [markdown]
# #### Initial score of `1.79717`

# %% [markdown]
# ## Step 4: Exploratory Data Analysis and Creating an additional feature
# * Any additional feature will do, but a great suggestion would be to separate out the datetime into hour, day, or month parts.

# %%
# Create a histogram of all features to show the distribution of each one relative to the data. This is part of the exploratory data analysis
train.hist(figsize=(20, 10))
plt.show()

# %%
# create a new feature for train
train["hour"] = train["datetime"].dt.hour
train["day"] = train["datetime"].dt.day
train["month"] = train["datetime"].dt.month

# %%
# create a new feature for test
test["hour"] = test["datetime"].dt.hour
test["day"] = test["datetime"].dt.day
test["month"] = test["datetime"].dt.month

# %% [markdown]
# ## Make category types for these so models know they are not just numbers
# * AutoGluon originally sees these as ints, but in reality they are int representations of a category.
# * Setting the dtype to category will classify these as categories in AutoGluon.

# %%
train["season"] = train["season"].astype(dtype="category")
train["weather"] = train["weather"].astype(dtype="category")
test["season"] = test["season"].astype(dtype="category")
test["weather"] = test["weather"].astype(dtype="category")

# %%
# View are new feature
train.head()
# Out:
#              datetime season  holiday  workingday weather  temp   atemp  \
# 0 2011-01-01 00:00:00      1        0           0       1  9.84  14.395
# 1 2011-01-01 01:00:00      1        0           0       1  9.02  13.635
# 2 2011-01-01 02:00:00      1        0           0       1  9.02  13.635
# 3 2011-01-01 03:00:00      1        0           0       1  9.84  14.395
# 4 2011-01-01 04:00:00      1        0           0       1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  hour  day  month
# 0        81        0.0       3          13     16     0    1      1
# 1        80        0.0       8          32     40     1    1      1
# 2        80        0.0       5          27     32     2    1      1
# 3        75        0.0       3          10     13     3    1      1
# 4        75        0.0       0           1      1     4    1      1

# %%
# View histogram of all features again now with the hour feature
train.hist(figsize=(20, 10))
plt.show()

# %%
# Scatter plots to visualize correlations
pd.plotting.scatter_matrix(train, figsize=(20, 10))
plt.show()

# %% [markdown]
# ## Step 5: Rerun the model with the same settings as before, just with more features

# %%
predictor_new_features = TabularPredictor(label="count").fit(
    train_data=train.drop(labels=["casual", "registered"], axis=1),
    time_limit=600,
    presets="best_quality"
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240502_204234"
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 600 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels\ag-20240502_204234\ds_sub_fit\sub_fit_ho.
# Running the sub-fit in a ray process to avoid memory leakage.
# Spend 166 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 434 seconds.
# Starting full fit now with num_stack_levels 1.
# Beginning AutoGluon training ... Time limit = 434s
# AutoGluon will save models to "AutogluonModels\ag-20240502_204234"
# =================== System Info ===================
# AutoGluon Version:  1.1.0
# Python Version:     3.10.6
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       4.00 GB / 15.72 GB (25.4%)
# Disk Space Avail:   288.50 GB / 375.98 GB (76.7%)
# ===================================================
# Train Data Rows:    10886
# Train Data Columns: 12
# Label Column:       count
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    4095.89 MB
# 	Train Data (Original)  Memory Usage: 0.73 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 2 | ['season', 'weather']
# 		('datetime', []) : 1 | ['datetime']
# 		('float', [])    : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])      : 6 | ['holiday', 'workingday', 'humidity', 'hour', 'day', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])             : 2 | ['season', 'weather']
# 		('float', [])                : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])                  : 4 | ['humidity', 'hour', 'day', 'month']
# 		('int', ['bool'])            : 2 | ['holiday', 'workingday']
# 		('int', ['datetime_as_int']) : 3 | ['datetime', 'datetime.year', 'datetime.dayofweek']
# 	0.7s = Fit runtime
# 	12 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.75 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.71s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 288.78s of the 433.25s of remaining time.
# 	-101.5882	 = Validation score   (-root_mean_squared_error)
# 	0.04s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 288.57s of the 433.04s of remaining time.
# 	-84.1464	 = Validation score   (-root_mean_squared_error)
# 	0.04s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 288.41s of the 432.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# 	-34.519	 = Validation score   (-root_mean_squared_error)
# 	39.31s	 = Training   runtime
# 	18.94s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 239.19s of the 383.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# 	-33.9169	 = Validation score   (-root_mean_squared_error)
# 	19.61s	 = Training   runtime
# 	5.89s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 208.81s of the 353.28s of remaining time.
# 	-38.409	 = Validation score   (-root_mean_squared_error)
# 	12.1s	 = Training   runtime
# 	0.71s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 195.46s of the 339.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.25%)
# 	-34.9104	 = Validation score   (-root_mean_squared_error)
# 	158.3s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 32.04s of the 176.51s of remaining time.
# 	-38.5125	 = Validation score   (-root_mean_squared_error)
# 	4.38s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 26.62s of the 171.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.18%)
# 	-48.8406	 = Validation score   (-root_mean_squared_error)
# 	33.39s	 = Training   runtime
# 	1.81s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 133.63s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L1': 0.36, 'LightGBMXT_BAG_L1': 0.32, 'CatBoost_BAG_L1': 0.16, 'RandomForestMSE_BAG_L1': 0.12, 'KNeighborsDist_BAG_L1': 0.04}
# 	-32.3373	 = Validation score   (-root_mean_squared_error)
# 	0.1s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 133.47s of the 133.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# 	-31.1589	 = Validation score   (-root_mean_squared_error)
# 	6.95s	 = Training   runtime
# 	1.09s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 121.09s of the 120.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.23%)
# 	-30.5749	 = Validation score   (-root_mean_squared_error)
# 	5.32s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 112.01s of the 111.9s of remaining time.
# 	-31.83	 = Validation score   (-root_mean_squared_error)
# 	28.26s	 = Training   runtime
# 	0.67s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 82.61s of the 82.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	-31.5518	 = Validation score   (-root_mean_squared_error)
# 	67.04s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 12.33s of the 12.23s of remaining time.
# 	-31.6816	 = Validation score   (-root_mean_squared_error)
# 	51.91s	 = Training   runtime
# 	1.41s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -42.88s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L2': 0.6, 'LightGBMXT_BAG_L2': 0.24, 'CatBoost_BAG_L2': 0.12, 'CatBoost_BAG_L1': 0.04}
# 	-30.347	 = Validation score   (-root_mean_squared_error)
# 	0.08s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 477.02s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240502_204234")

# %%
predictor_new_features.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model   score_val              eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L3  -30.346962  root_mean_squared_error      29.935681  346.563470                0.000000           0.079609            3       True         15
# 1          LightGBM_BAG_L2  -30.574852  root_mean_squared_error      28.553090  272.490207                0.426389           5.323279            2       True         11
# 2        LightGBMXT_BAG_L2  -31.158895  root_mean_squared_error      29.213443  274.115681                1.086742           6.948753            2       True         10
# 3          CatBoost_BAG_L2  -31.551772  root_mean_squared_error      28.422551  334.211829                0.295850          67.044901            2       True         13
# 4     ExtraTreesMSE_BAG_L2  -31.681604  root_mean_squared_error      29.532698  319.080566                1.405996          51.913637            2       True         14
# 5   RandomForestMSE_BAG_L2  -31.830038  root_mean_squared_error      28.798138  295.426660                0.671437          28.259732            2       True         12
# 6      WeightedEnsemble_L2  -32.337316  root_mean_squared_error      25.688809  229.459450                0.001993           0.101158            2       True          9
# 7          LightGBM_BAG_L1  -33.916920  root_mean_squared_error       5.885478   19.609624                5.885478          19.609624            1       True          4
# 8        LightGBMXT_BAG_L1  -34.519031  root_mean_squared_error      18.938055   39.306385               18.938055          39.306385            1       True          3
# 9          CatBoost_BAG_L1  -34.910425  root_mean_squared_error       0.085276  158.296763                0.085276         158.296763            1       True          6
# 10  RandomForestMSE_BAG_L1  -38.409035  root_mean_squared_error       0.711979   12.103541                0.711979          12.103541            1       True          5
# 11    ExtraTreesMSE_BAG_L1  -38.512506  root_mean_squared_error       0.574922    4.381992                0.574922           4.381992            1       True          7
# 12  NeuralNetFastAI_BAG_L1  -48.840589  root_mean_squared_error       1.813960   33.389644                1.813960          33.389644            1       True          8
# 13   KNeighborsDist_BAG_L1  -84.146423  root_mean_squared_error       0.066029    0.041979                0.066029           0.041979            1       True          2
# 14   KNeighborsUnif_BAG_L1 -101.588176  root_mean_squared_error       0.051003    0.037000                0.051003           0.037000            1       True          1
# Number of models trained: 15
# Types of models trained:
# {'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_CatBoost', 'WeightedEnsembleModel', 'StackerEnsembleModel_RF'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])             : 2 | ['season', 'weather']
# ('float', [])                : 3 | ['temp', 'atemp', 'windspeed']
# ('int', [])                  : 4 | ['humidity', 'hour', 'day', 'month']
# ('int', ['bool'])            : 2 | ['holiday', 'workingday']
# ('int', ['datetime_as_int']) : 3 | ['datetime', 'datetime.year', 'datetime.dayofweek']
# *** End of fit() summary ***
# C:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L2': 'StackerEnsembleModel_XT',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': -101.58817625927213,
#   'KNeighborsDist_BAG_L1': -84.14642264302962,
#   'LightGBMXT_BAG_L1': -34.51903091052072,
#   'LightGBM_BAG_L1': -33.916920183145294,
#   'RandomForestMSE_BAG_L1': -38.40903471996817,
#   'CatBoost_BAG_L1': -34.91042549191486,
#   'ExtraTreesMSE_BAG_L1': -38.51250617595346,
#   'NeuralNetFastAI_BAG_L1': -48.84058915915011,
#   'WeightedEnsemble_L2': -32.337316094885644,
#   'LightGBMXT_BAG_L2': -31.158895348382313,
#   'LightGBM_BAG_L2': -30.574852370635575,
#   'RandomForestMSE_BAG_L2': -31.830038308940274,
#   'CatBoost_BAG_L2': -31.551772208930515,
#   'ExtraTreesMSE_BAG_L2': -31.681604190659225,
#   'WeightedEnsemble_L3': -30.346962166774453},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestMSE_BAG_L1': ['RandomForestMSE_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesMSE_BAG_L1': ['ExtraTreesMSE_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestMSE_BAG_L2': ['RandomForestMSE_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesMSE_BAG_L2': ['ExtraTreesMSE_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.037000179290771484,
#   'KNeighborsDist_BAG_L1': 0.041979312896728516,
#   'LightGBMXT_BAG_L1': 39.306384801864624,
#   'LightGBM_BAG_L1': 19.60962438583374,
#   'RandomForestMSE_BAG_L1': 12.103540897369385,
#   'CatBoost_BAG_L1': 158.29676270484924,
#   'ExtraTreesMSE_BAG_L1': 4.3819921016693115,
#   'NeuralNetFastAI_BAG_L1': 33.389644145965576,
#   'WeightedEnsemble_L2': 0.10115790367126465,
#   'LightGBMXT_BAG_L2': 6.9487526416778564,
#   'LightGBM_BAG_L2': 5.323278903961182,
#   'RandomForestMSE_BAG_L2': 28.25973153114319,
#   'CatBoost_BAG_L2': 67.04490089416504,
#   'ExtraTreesMSE_BAG_L2': 51.91363739967346,
#   'WeightedEnsemble_L3': 0.07960867881774902},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.05100297927856445,
#   'KNeighborsDist_BAG_L1': 0.06602907180786133,
#   'LightGBMXT_BAG_L1': 18.93805480003357,
#   'LightGBM_BAG_L1': 5.885477542877197,
#   'RandomForestMSE_BAG_L1': 0.7119786739349365,
#   'CatBoost_BAG_L1': 0.08527636528015137,
#   'ExtraTreesMSE_BAG_L1': 0.5749220848083496,
#   'NeuralNetFastAI_BAG_L1': 1.8139598369598389,
#   'WeightedEnsemble_L2': 0.0019927024841308594,
#   'LightGBMXT_BAG_L2': 1.0867419242858887,
#   'LightGBM_BAG_L2': 0.4263885021209717,
#   'RandomForestMSE_BAG_L2': 0.6714365482330322,
#   'CatBoost_BAG_L2': 0.2958495616912842,
#   'ExtraTreesMSE_BAG_L2': 1.405996322631836,
#   'WeightedEnsemble_L3': 0.0},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                      model   score_val              eval_metric  \
#  0      WeightedEnsemble_L3  -30.346962  root_mean_squared_error
#  1          LightGBM_BAG_L2  -30.574852  root_mean_squared_error
#  2        LightGBMXT_BAG_L2  -31.158895  root_mean_squared_error
#  3          CatBoost_BAG_L2  -31.551772  root_mean_squared_error
#  4     ExtraTreesMSE_BAG_L2  -31.681604  root_mean_squared_error
#  5   RandomForestMSE_BAG_L2  -31.830038  root_mean_squared_error
#  6      WeightedEnsemble_L2  -32.337316  root_mean_squared_error
#  7          LightGBM_BAG_L1  -33.916920  root_mean_squared_error
#  8        LightGBMXT_BAG_L1  -34.519031  root_mean_squared_error
#  9          CatBoost_BAG_L1  -34.910425  root_mean_squared_error
#  10  RandomForestMSE_BAG_L1  -38.409035  root_mean_squared_error
#  11    ExtraTreesMSE_BAG_L1  -38.512506  root_mean_squared_error
#  12  NeuralNetFastAI_BAG_L1  -48.840589  root_mean_squared_error
#  13   KNeighborsDist_BAG_L1  -84.146423  root_mean_squared_error
#  14   KNeighborsUnif_BAG_L1 -101.588176  root_mean_squared_error
#
#      pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  \
#  0       29.935681  346.563470                0.000000           0.079609
#  1       28.553090  272.490207                0.426389           5.323279
#  2       29.213443  274.115681                1.086742           6.948753
#  3       28.422551  334.211829                0.295850          67.044901
#  4       29.532698  319.080566                1.405996          51.913637
#  5       28.798138  295.426660                0.671437          28.259732
#  6       25.688809  229.459450                0.001993           0.101158
#  7        5.885478   19.609624                5.885478          19.609624
#  8       18.938055   39.306385               18.938055          39.306385
#  9        0.085276  158.296763                0.085276         158.296763
#  10       0.711979   12.103541                0.711979          12.103541
#  11       0.574922    4.381992                0.574922           4.381992
#  12       1.813960   33.389644                1.813960          33.389644
#  13       0.066029    0.041979                0.066029           0.041979
#  14       0.051003    0.037000                0.051003           0.037000
#
#      stack_level  can_infer  fit_order
#  0             3       True         15
#  1             2       True         11
#  2             2       True         10
#  3             2       True         13
#  4             2       True         14
#  5             2       True         12
#  6             2       True          9
#  7             1       True          4
#  8             1       True          3
#  9             1       True          6
#  10            1       True          5
#  11            1       True          7
#  12            1       True          8
#  13            1       True          2
#  14            1       True          1  }

# %%
predictions_new_features = predictor_new_features.predict(test)

# %%
# Remember to set all negative values to zero
predictions_new_features.loc[predictions_new_features < 0] = 0

# %%
# Same submitting predictions
submission_new_features = submission.copy()
submission_new_features["count"] = predictions_new_features
submission_new_features.to_csv("submission_new_features.csv", index=False)

# %%
# !kaggle competitions submit -c bike-sharing-demand -f submission_new_features.csv -m "new features"

# %%
# !kaggle competitions submissions -c bike-sharing-demand | tail -n +1 | head -n 6

# %% [markdown]
# #### New Score of `0.63236`

# %% [markdown]
# ## Step 6: Hyper parameter optimization
# * There are many options for hyper parameter optimization.
# * Options are to change the AutoGluon higher level parameters or the individual model hyperparameters.
# * The hyperparameters of the models themselves that are in AutoGluon. Those need the `hyperparameter` and `hyperparameter_tune_kwargs` arguments.

# %%
predictor_new_hpo = TabularPredictor(label="count").fit(
    train_data=train.drop(labels=["casual", "registered"], axis=1),
    time_limit=2000,
    presets="best_quality",
    auto_stack="True",
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240503_091655"
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 2000 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels\ag-20240503_091655\ds_sub_fit\sub_fit_ho.
# Running the sub-fit in a ray process to avoid memory leakage.
# Spend 620 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 1380 seconds.
# Starting full fit now with num_stack_levels 1.
# Beginning AutoGluon training ... Time limit = 1380s
# AutoGluon will save models to "AutogluonModels\ag-20240503_091655"
# =================== System Info ===================
# AutoGluon Version:  1.1.0
# Python Version:     3.10.6
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       3.63 GB / 15.72 GB (23.1%)
# Disk Space Avail:   283.43 GB / 375.98 GB (75.4%)
# ===================================================
# Train Data Rows:    10886
# Train Data Columns: 12
# Label Column:       count
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    3714.34 MB
# 	Train Data (Original)  Memory Usage: 0.73 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 2 | ['season', 'weather']
# 		('datetime', []) : 1 | ['datetime']
# 		('float', [])    : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])      : 6 | ['holiday', 'workingday', 'humidity', 'hour', 'day', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])             : 2 | ['season', 'weather']
# 		('float', [])                : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])                  : 4 | ['humidity', 'hour', 'day', 'month']
# 		('int', ['bool'])            : 2 | ['holiday', 'workingday']
# 		('int', ['datetime_as_int']) : 3 | ['datetime', 'datetime.year', 'datetime.dayofweek']
# 	1.0s = Fit runtime
# 	12 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.75 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.02s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 919.09s of the 1378.94s of remaining time.
# 	-101.5882	 = Validation score   (-root_mean_squared_error)
# 	0.07s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 918.72s of the 1378.58s of remaining time.
# 	-84.1464	 = Validation score   (-root_mean_squared_error)
# 	0.07s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 918.48s of the 1378.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.18%)
# 	-34.519	 = Validation score   (-root_mean_squared_error)
# 	40.05s	 = Training   runtime
# 	22.7s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 868.97s of the 1328.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.20%)
# 	-33.9169	 = Validation score   (-root_mean_squared_error)
# 	19.06s	 = Training   runtime
# 	5.81s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 843.32s of the 1303.17s of remaining time.
# 	-38.409	 = Validation score   (-root_mean_squared_error)
# 	11.25s	 = Training   runtime
# 	1.11s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 829.72s of the 1289.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# 	-33.3056	 = Validation score   (-root_mean_squared_error)
# 	664.62s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 158.5s of the 618.36s of remaining time.
# 	-38.5125	 = Validation score   (-root_mean_squared_error)
# 	5.5s	 = Training   runtime
# 	0.74s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 151.65s of the 611.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# 	-46.6004	 = Validation score   (-root_mean_squared_error)
# 	48.82s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 97.87s of the 557.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.31%)
# 	-34.6064	 = Validation score   (-root_mean_squared_error)
# 	17.35s	 = Training   runtime
# 	2.14s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 74.44s of the 534.29s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	-50.9145	 = Validation score   (-root_mean_squared_error)
# 	68.19s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1.7s of the 461.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.45%)
# 	-35.019	 = Validation score   (-root_mean_squared_error)
# 	2.96s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 453.06s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.28, 'LightGBMXT_BAG_L1': 0.24, 'LightGBM_BAG_L1': 0.16, 'XGBoost_BAG_L1': 0.12, 'RandomForestMSE_BAG_L1': 0.08, 'LightGBMLarge_BAG_L1': 0.08, 'KNeighborsDist_BAG_L1': 0.04}
# 	-32.038	 = Validation score   (-root_mean_squared_error)
# 	0.1s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 452.9s of the 452.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.29%)
# 	-31.0977	 = Validation score   (-root_mean_squared_error)
# 	10.41s	 = Training   runtime
# 	1.51s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 436.0s of the 435.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# 	-30.5394	 = Validation score   (-root_mean_squared_error)
# 	6.54s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 425.2s of the 425.1s of remaining time.
# 	-31.6829	 = Validation score   (-root_mean_squared_error)
# 	42.21s	 = Training   runtime
# 	0.84s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 381.52s of the 381.42s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.40%)
# 	-30.2533	 = Validation score   (-root_mean_squared_error)
# 	306.12s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 72.41s of the 72.31s of remaining time.
# 	-31.5317	 = Validation score   (-root_mean_squared_error)
# 	9.73s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 61.3s of the 61.2s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	-29.683	 = Validation score   (-root_mean_squared_error)
# 	43.89s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 14.12s of the 14.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	-30.8145	 = Validation score   (-root_mean_squared_error)
# 	9.12s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -1.46s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L2': 0.591, 'CatBoost_BAG_L2': 0.227, 'LightGBM_BAG_L2': 0.091, 'XGBoost_BAG_L2': 0.091}
# 	-29.3134	 = Validation score   (-root_mean_squared_error)
# 	0.1s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1381.61s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240503_091655")

# %%
predictor_new_hpo.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model   score_val              eval_metric  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L3  -29.313353  root_mean_squared_error      35.749486  1243.702504                0.001003           0.102097            3       True         20
# 1   NeuralNetFastAI_BAG_L2  -29.682967  root_mean_squared_error      34.942532   921.826644                0.581369          43.888157            2       True         18
# 2          CatBoost_BAG_L2  -30.253317  root_mean_squared_error      34.520764  1184.056830                0.159601         306.118343            2       True         16
# 3          LightGBM_BAG_L2  -30.539360  root_mean_squared_error      34.757302   884.477138                0.396139           6.538651            2       True         14
# 4           XGBoost_BAG_L2  -30.814502  root_mean_squared_error      34.611374   887.055256                0.250211           9.116768            2       True         19
# 5        LightGBMXT_BAG_L2  -31.097656  root_mean_squared_error      35.874569   888.347204                1.513406          10.408717            2       True         13
# 6     ExtraTreesMSE_BAG_L2  -31.531666  root_mean_squared_error      35.164900   887.668328                0.803737           9.729841            2       True         17
# 7   RandomForestMSE_BAG_L2  -31.682940  root_mean_squared_error      35.203057   920.145531                0.841894          42.207044            2       True         15
# 8      WeightedEnsemble_L2  -32.037998  root_mean_squared_error      32.649710   755.466854                0.001994           0.103022            2       True         12
# 9          CatBoost_BAG_L1  -33.305553  root_mean_squared_error       0.472734   664.619572                0.472734         664.619572            1       True          6
# 10         LightGBM_BAG_L1  -33.916920  root_mean_squared_error       5.808042    19.063883                5.808042          19.063883            1       True          4
# 11       LightGBMXT_BAG_L1  -34.519031  root_mean_squared_error      22.697529    40.054257               22.697529          40.054257            1       True          3
# 12          XGBoost_BAG_L1  -34.606395  root_mean_squared_error       2.141737    17.347142                2.141737          17.347142            1       True          9
# 13    LightGBMLarge_BAG_L1  -35.019005  root_mean_squared_error       0.314003     2.964471                0.314003           2.964471            1       True         11
# 14  RandomForestMSE_BAG_L1  -38.409035  root_mean_squared_error       1.113473    11.249463                1.113473          11.249463            1       True          5
# 15    ExtraTreesMSE_BAG_L1  -38.512506  root_mean_squared_error       0.739140     5.495370                0.739140           5.495370            1       True          7
# 16  NeuralNetFastAI_BAG_L1  -46.600420  root_mean_squared_error       0.579147    48.817882                0.579147          48.817882            1       True          8
# 17   NeuralNetTorch_BAG_L1  -50.914482  root_mean_squared_error       0.256204    68.186464                0.256204          68.186464            1       True         10
# 18   KNeighborsDist_BAG_L1  -84.146423  root_mean_squared_error       0.100198     0.065044                0.100198           0.065044            1       True          2
# 19   KNeighborsUnif_BAG_L1 -101.588176  root_mean_squared_error       0.138956     0.074940                0.138956           0.074940            1       True          1
# Number of models trained: 20
# Types of models trained:
# {'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_CatBoost', 'WeightedEnsembleModel', 'StackerEnsembleModel_RF'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])             : 2 | ['season', 'weather']
# ('float', [])                : 3 | ['temp', 'atemp', 'windspeed']
# ('int', [])                  : 4 | ['humidity', 'hour', 'day', 'month']
# ('int', ['bool'])            : 2 | ['holiday', 'workingday']
# ('int', ['datetime_as_int']) : 3 | ['datetime', 'datetime.year', 'datetime.dayofweek']
# *** End of fit() summary ***
# C:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': -101.58817625927213,
#   'KNeighborsDist_BAG_L1': -84.14642264302962,
#   'LightGBMXT_BAG_L1': -34.51903091052072,
#   'LightGBM_BAG_L1': -33.916920183145294,
#   'RandomForestMSE_BAG_L1': -38.40903471996817,
#   'CatBoost_BAG_L1': -33.30555293707195,
#   'ExtraTreesMSE_BAG_L1': -38.51250617595346,
#   'NeuralNetFastAI_BAG_L1': -46.60042043733904,
#   'XGBoost_BAG_L1': -34.606394810725135,
#   'NeuralNetTorch_BAG_L1': -50.91448233011463,
#   'LightGBMLarge_BAG_L1': -35.019004748385605,
#   'WeightedEnsemble_L2': -32.03799815587564,
#   'LightGBMXT_BAG_L2': -31.097656377887823,
#   'LightGBM_BAG_L2': -30.53935962786858,
#   'RandomForestMSE_BAG_L2': -31.68293973136471,
#   'CatBoost_BAG_L2': -30.253317326596594,
#   'ExtraTreesMSE_BAG_L2': -31.53166626200828,
#   'NeuralNetFastAI_BAG_L2': -29.68296734735138,
#   'XGBoost_BAG_L2': -30.814501722274628,
#   'WeightedEnsemble_L3': -29.313353236567725},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestMSE_BAG_L1': ['RandomForestMSE_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesMSE_BAG_L1': ['ExtraTreesMSE_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestMSE_BAG_L2': ['RandomForestMSE_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesMSE_BAG_L2': ['ExtraTreesMSE_BAG_L2'],
#   'NeuralNetFastAI_BAG_L2': ['NeuralNetFastAI_BAG_L2'],
#   'XGBoost_BAG_L2': ['XGBoost_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.07493972778320312,
#   'KNeighborsDist_BAG_L1': 0.06504416465759277,
#   'LightGBMXT_BAG_L1': 40.05425715446472,
#   'LightGBM_BAG_L1': 19.06388258934021,
#   'RandomForestMSE_BAG_L1': 11.249462842941284,
#   'CatBoost_BAG_L1': 664.6195724010468,
#   'ExtraTreesMSE_BAG_L1': 5.495370388031006,
#   'NeuralNetFastAI_BAG_L1': 48.81788158416748,
#   'XGBoost_BAG_L1': 17.34714150428772,
#   'NeuralNetTorch_BAG_L1': 68.18646359443665,
#   'LightGBMLarge_BAG_L1': 2.9644713401794434,
#   'WeightedEnsemble_L2': 0.10302186012268066,
#   'LightGBMXT_BAG_L2': 10.408717155456543,
#   'LightGBM_BAG_L2': 6.538650989532471,
#   'RandomForestMSE_BAG_L2': 42.20704364776611,
#   'CatBoost_BAG_L2': 306.11834263801575,
#   'ExtraTreesMSE_BAG_L2': 9.729840755462646,
#   'NeuralNetFastAI_BAG_L2': 43.88815712928772,
#   'XGBoost_BAG_L2': 9.11676836013794,
#   'WeightedEnsemble_L3': 0.1020972728729248},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.13895583152770996,
#   'KNeighborsDist_BAG_L1': 0.10019826889038086,
#   'LightGBMXT_BAG_L1': 22.69752860069275,
#   'LightGBM_BAG_L1': 5.808042049407959,
#   'RandomForestMSE_BAG_L1': 1.1134734153747559,
#   'CatBoost_BAG_L1': 0.4727342128753662,
#   'ExtraTreesMSE_BAG_L1': 0.7391397953033447,
#   'NeuralNetFastAI_BAG_L1': 0.5791468620300293,
#   'XGBoost_BAG_L1': 2.1417365074157715,
#   'NeuralNetTorch_BAG_L1': 0.25620412826538086,
#   'LightGBMLarge_BAG_L1': 0.31400322914123535,
#   'WeightedEnsemble_L2': 0.001993894577026367,
#   'LightGBMXT_BAG_L2': 1.5134057998657227,
#   'LightGBM_BAG_L2': 0.39613938331604004,
#   'RandomForestMSE_BAG_L2': 0.8418939113616943,
#   'CatBoost_BAG_L2': 0.15960097312927246,
#   'ExtraTreesMSE_BAG_L2': 0.803736686706543,
#   'NeuralNetFastAI_BAG_L2': 0.5813689231872559,
#   'XGBoost_BAG_L2': 0.250211238861084,
#   'WeightedEnsemble_L3': 0.0010030269622802734},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                      model   score_val              eval_metric  \
#  0      WeightedEnsemble_L3  -29.313353  root_mean_squared_error
#  1   NeuralNetFastAI_BAG_L2  -29.682967  root_mean_squared_error
#  2          CatBoost_BAG_L2  -30.253317  root_mean_squared_error
#  3          LightGBM_BAG_L2  -30.539360  root_mean_squared_error
#  4           XGBoost_BAG_L2  -30.814502  root_mean_squared_error
#  5        LightGBMXT_BAG_L2  -31.097656  root_mean_squared_error
#  6     ExtraTreesMSE_BAG_L2  -31.531666  root_mean_squared_error
#  7   RandomForestMSE_BAG_L2  -31.682940  root_mean_squared_error
#  8      WeightedEnsemble_L2  -32.037998  root_mean_squared_error
#  9          CatBoost_BAG_L1  -33.305553  root_mean_squared_error
#  10         LightGBM_BAG_L1  -33.916920  root_mean_squared_error
#  11       LightGBMXT_BAG_L1  -34.519031  root_mean_squared_error
#  12          XGBoost_BAG_L1  -34.606395  root_mean_squared_error
#  13    LightGBMLarge_BAG_L1  -35.019005  root_mean_squared_error
#  14  RandomForestMSE_BAG_L1  -38.409035  root_mean_squared_error
#  15    ExtraTreesMSE_BAG_L1  -38.512506  root_mean_squared_error
#  16  NeuralNetFastAI_BAG_L1  -46.600420  root_mean_squared_error
#  17   NeuralNetTorch_BAG_L1  -50.914482  root_mean_squared_error
#  18   KNeighborsDist_BAG_L1  -84.146423  root_mean_squared_error
#  19   KNeighborsUnif_BAG_L1 -101.588176  root_mean_squared_error
#
#      pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  \
#  0       35.749486  1243.702504                0.001003           0.102097
#  1       34.942532   921.826644                0.581369          43.888157
#  2       34.520764  1184.056830                0.159601         306.118343
#  3       34.757302   884.477138                0.396139           6.538651
#  4       34.611374   887.055256                0.250211           9.116768
#  5       35.874569   888.347204                1.513406          10.408717
#  6       35.164900   887.668328                0.803737           9.729841
#  7       35.203057   920.145531                0.841894          42.207044
#  8       32.649710   755.466854                0.001994           0.103022
#  9        0.472734   664.619572                0.472734         664.619572
#  10       5.808042    19.063883                5.808042          19.063883
#  11      22.697529    40.054257               22.697529          40.054257
#  12       2.141737    17.347142                2.141737          17.347142
#  13       0.314003     2.964471                0.314003           2.964471
#  14       1.113473    11.249463                1.113473          11.249463
#  15       0.739140     5.495370                0.739140           5.495370
#  16       0.579147    48.817882                0.579147          48.817882
#  17       0.256204    68.186464                0.256204          68.186464
#  18       0.100198     0.065044                0.100198           0.065044
#  19       0.138956     0.074940                0.138956           0.074940
#
#      stack_level  can_infer  fit_order
#  0             3       True         20
#  1             2       True         18
#  2             2       True         16
#  3             2       True         14
#  4             2       True         19
#  5             2       True         13
#  6             2       True         17
#  7             2       True         15
#  8             2       True         12
#  9             1       True          6
#  10            1       True          4
#  11            1       True          3
#  12            1       True          9
#  13            1       True         11
#  14            1       True          5
#  15            1       True          7
#  16            1       True          8
#  17            1       True         10
#  18            1       True          2
#  19            1       True          1  }

# %%
# Remember to set all negative values to zero
predictions_new_hpo = predictor_new_hpo.predict(test)
predictions_new_hpo.loc[predictions_new_hpo < 0] = 0

# %%
# Same submitting predictions
submission_new_hpo = submission.copy()
submission_new_hpo["count"] = predictions_new_hpo
submission_new_hpo.to_csv("submission_new_hpo.csv", index=False)

# %%
# !kaggle competitions submit -c bike-sharing-demand -f submission_new_hpo.csv -m "new features with hyperparameters"

# %%
# !kaggle competitions submissions -c bike-sharing-demand | tail -n +1 | head -n 6

# %% [markdown]
# #### New Score of `0.63236`

# %% [markdown]
# ## Step 7: Write a Report
# ### Refer to the markdown file for the full report
# ### Creating plots and table for report

# %%
# Taking the top model score from each training run and creating a line plot to show improvement
# You can create these in the notebook and save them to PNG or use some other tool (e.g. google sheets, excel)
fig = pd.DataFrame(
    {
        "model": ["initial", "add_features", "hpo"],
        "score": [-53.1787, -30.3469, -29.31]
    }
).plot(x="model", y="score", figsize=(8, 6)).get_figure()
fig.savefig('model_train_score.png')

# %%
# Take the 3 kaggle scores and creating a line plot to show improvement
fig = pd.DataFrame(
    {
        "test_eval": ["initial", "add_features", "hpo"],
        "score": [1.79717, 0.75790, 0.63236]
    }
).plot(x="test_eval", y="score", figsize=(8, 6)).get_figure()
fig.savefig('model_test_score.png')

# %% [markdown]
# ### Hyperparameter table

# %%
# The 3 hyperparameters we tuned with the kaggle score as the result
pd.DataFrame({
    "model": ["initial", "add_features", "hpo"],
    "hpo1": ["time_limit", "time_limit", "time_limit"],
    "hpo2": ["presets", "presets", "presets"],
    "hpo3": ["-", "-", "auto_stack"],
    "score": [1.79717, 0.75790, 0.63236]
})
